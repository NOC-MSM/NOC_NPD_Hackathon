# %% [markdown]
# ## **NOC Near-Present Day Hackathon - Science Themes**
# ### Example: 2. Atlantic Overturning in a Changing Climate
#
# #### **Contact:**
# Ollie Tooth (oliver.tooth@noc.ac.uk)
#
# #### **Description:**
# ---
#
# This Notebook includes example code as a starting point for the Science Theme II: Atlantic Overturning in a Changing Climate group analysis.
#
# This includes:
#
# * Creating example NEMODataTrees to analyse AMOC connectivity in the NOC Near-Present Day hierarchy.
#
# * Accessing pre-calculated AMOC diagnostics via OceanDataCatalog for inter-model comparison.
#
# * Accessing available AMOC observational datasets via the JASMIN cloud object store.

# %% [markdown]
# #### **1.1 Creating NEMODataTrees**
# ---
#
# * Let's begin by importing the **NEMO Cookbook** Python library and the `NEMODataTree` class:

# %%
import xarray as xr

from nemo_cookbook import NEMODataTree
from OceanDataStore import OceanDataCatalog

# %% [markdown]
# * Creating a `NEMODataTree` from the **eORCA1 ERA5v1** monthly-mean meridional velocity outputs using the **OceanDataCatalog**:

# %%
# Initialising the OceanDataCatalog using the `noc-stac` stored in the JASMIN cloud object store:
catalog = OceanDataCatalog(catalog_name="noc-stac")

# %%
# Open eORCA1 ERA5 v1 domain_cfg ancillary dataset:
ds_domain_cfg = catalog.open_dataset(id="noc-npd-era5/npd-eorca1-era5v1/r1i1c1f1/gn/domain/domain_cfg")
# Open eORCA1 ERA5 v1 gridV dataset:
ds_gridV = catalog.open_dataset(id="noc-npd-era5/npd-eorca1-era5v1/r1i1c1f1/gn/V1m")

ds_gridV
# Out:
# <xarray.Dataset> Size: 108GB
# Dimensions:               (time_counter: 595, y: 331, x: 360, depthv: 75,
#                            axis_nbounds: 2)
# Coordinates:
#   * time_counter          (time_counter) datetime64[ns] 5kB 1976-01-16T12:00:...
#     time_centered         (time_counter) datetime64[ns] 5kB dask.array<chunksize=(1,), meta=np.ndarray>
#     nav_lon               (y, x) float64 953kB dask.array<chunksize=(331, 360), meta=np.ndarray>
#     nav_lat               (y, x) float64 953kB dask.array<chunksize=(331, 360), meta=np.ndarray>
#   * depthv                (depthv) float32 300B 0.5058 1.556 ... 5.902e+03
# Dimensions without coordinates: y, x, axis_nbounds
# Data variables: (12/13)
#     hfy                   (time_counter, y, x) float32 284MB dask.array<chunksize=(1, 331, 360), meta=np.ndarray>
#     e3v                   (time_counter, depthv, y, x) float32 21GB dask.array<chunksize=(1, 25, 331, 360), meta=np.ndarray>
# ...

# %%
# Define datasets dictionary:
datasets = {"parent": {"domain": ds_domain_cfg, "gridV": ds_gridV}}

# Create NEMODataTree from eORCA1 ERA5 v1 datasets:
nemo_eorca1 = NEMODataTree.from_datasets(datasets=datasets, iperio=True, nftype="F", read_mask=False)

nemo_eorca1
# Out:
# <xarray.DataTree 'NEMO model'>
# Group: /
# │   Dimensions:               (time_counter: 595, axis_nbounds: 2)
# │   Coordinates:
# │     * time_counter          (time_counter) datetime64[ns] 5kB 1976-01-16T12:00:...
# │       time_centered         (time_counter) datetime64[ns] 5kB dask.array<chunksize=(1,), meta=np.ndarray>
# │   Dimensions without coordinates: axis_nbounds
# │   Data variables:
# │       time_counter_bounds   (time_counter, axis_nbounds) datetime64[ns] 10kB dask.array<chunksize=(1, 2), meta=np.ndarray>
# │       time_centered_bounds  (time_counter, axis_nbounds) datetime64[ns] 10kB dask.array<chunksize=(1, 2), meta=np.ndarray>
# │   Attributes:
# │       nftype:   F
# │       iperio:   True
# ├── Group: /gridT
# │       Dimensions:       (j: 331, i: 360, k: 75)
# │       Coordinates:
# │         * j             (j) int64 3kB 1 2 3 4 5 6 7 8 ... 325 326 327 328 329 330 331
# │         * i             (i) int64 3kB 1 2 3 4 5 6 7 8 ... 354 355 356 357 358 359 360
# ...

# %% [markdown]
# * Creating a `NEMODataTree` from the **eORCA025 ERA5v1** monthly-mean meridional velocity outputs using the **OceanDataCatalog**:

# %%
# Open eORCA025 ERA5 v1 domain_cfg ancillary dataset:
ds_domain_cfg = catalog.open_dataset(id="noc-npd-era5/npd-eorca025-era5v1/r1i1c1f1/gn/domain/domain_cfg")
# Open eORCA025 ERA5 v1 gridV dataset:
ds_gridV = catalog.open_dataset(id="noc-npd-era5/npd-eorca025-era5v1/r1i1c1f1/gn/V1m_4d")

ds_gridV
# Out:
# <xarray.Dataset> Size: 2TB
# Dimensions:               (time_counter: 595, axis_nbounds: 2, depthv: 75,
#                            y: 1206, x: 1440)
# Coordinates:
#   * time_counter          (time_counter) datetime64[ns] 5kB 1976-01-16T12:00:...
#     time_centered         (time_counter) datetime64[ns] 5kB dask.array<chunksize=(1,), meta=np.ndarray>
#   * depthv                (depthv) float32 300B 0.5058 1.556 ... 5.902e+03
#     nav_lat               (y, x) float64 14MB dask.array<chunksize=(603, 720), meta=np.ndarray>
#     nav_lon               (y, x) float64 14MB dask.array<chunksize=(603, 720), meta=np.ndarray>
# Dimensions without coordinates: axis_nbounds, y, x
# Data variables:
#     time_counter_bounds   (time_counter, axis_nbounds) datetime64[ns] 10kB dask.array<chunksize=(1, 2), meta=np.ndarray>
#     time_centered_bounds  (time_counter, axis_nbounds) datetime64[ns] 10kB dask.array<chunksize=(1, 2), meta=np.ndarray>
# ...

# %%
# Define datasets dictionary:
datasets = {"parent": {"domain": ds_domain_cfg, "gridV": ds_gridV}}

# Create NEMODataTree from eORCA025 ERA5 v1 datasets:
nemo_eorca025 = NEMODataTree.from_datasets(datasets=datasets, iperio=True, nftype="T", read_mask=False)

nemo_eorca025
# Out:
# <xarray.DataTree 'NEMO model'>
# Group: /
# │   Dimensions:               (time_counter: 595, axis_nbounds: 2)
# │   Coordinates:
# │     * time_counter          (time_counter) datetime64[ns] 5kB 1976-01-16T12:00:...
# │       time_centered         (time_counter) datetime64[ns] 5kB dask.array<chunksize=(1,), meta=np.ndarray>
# │   Dimensions without coordinates: axis_nbounds
# │   Data variables:
# │       time_counter_bounds   (time_counter, axis_nbounds) datetime64[ns] 10kB dask.array<chunksize=(1, 2), meta=np.ndarray>
# │       time_centered_bounds  (time_counter, axis_nbounds) datetime64[ns] 10kB dask.array<chunksize=(1, 2), meta=np.ndarray>
# │   Attributes:
# │       nftype:   T
# │       iperio:   True
# ├── Group: /gridT
# │       Dimensions:       (j: 1206, i: 1440, k: 75)
# │       Coordinates:
# │         * j             (j) int64 10kB 1 2 3 4 5 6 7 ... 1201 1202 1203 1204 1205 1206
# │         * i             (i) int64 12kB 1 2 3 4 5 6 7 ... 1435 1436 1437 1438 1439 1440
# ...

# %% [markdown]
# * Creating a `NEMODataTree` from the **eORCA12 ERA5v1** monthly-mean meridional velocity outputs using the **OceanDataCatalog**:

# %%
# Open eORCA12 ERA5 v1 domain_cfg ancillary dataset:
ds_domain_cfg = catalog.open_dataset(id="noc-npd-era5/npd-eorca12-era5v1/r1i1c1f1/gn/domain/domain_cfg")
# Open eORCA12 ERA5 v1 gridV dataset:
ds_gridV = catalog.open_dataset(id="noc-npd-era5/npd-eorca12-era5v1/r1i1c1f1/gn/V1m_4d")

ds_gridV
# Out:
# <xarray.Dataset> Size: 11TB
# Dimensions:               (time_counter: 594, depthv: 75, y: 3605, x: 4320,
#                            axis_nbounds: 2)
# Coordinates:
#   * time_counter          (time_counter) datetime64[ns] 5kB 1976-01-16T12:00:...
#     time_centered         (time_counter) datetime64[ns] 5kB dask.array<chunksize=(1,), meta=np.ndarray>
#   * depthv                (depthv) float32 300B 0.5058 1.556 ... 5.902e+03
#   * y                     (y) int64 29kB 0 1 2 3 4 ... 3600 3601 3602 3603 3604
#   * x                     (x) int64 35kB 0 1 2 3 4 ... 4315 4316 4317 4318 4319
#     nav_lat               (y, x) float64 125MB dask.array<chunksize=(721, 540), meta=np.ndarray>
#     nav_lon               (y, x) float64 125MB dask.array<chunksize=(721, 540), meta=np.ndarray>
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     v2o                   (time_counter, depthv, y, x) float32 3TB dask.array<chunksize=(1, 25, 721, 540), meta=np.ndarray>
# ...

# %%
# Define datasets dictionary:
datasets = {"parent": {"domain": ds_domain_cfg, "gridV": ds_gridV}}

# Create NEMODataTree from eORCA12 ERA5 v1 datasets:
nemo_eorca12 = NEMODataTree.from_datasets(datasets=datasets, iperio=True, nftype="T", read_mask=True)

nemo_eorca12
# Out:
# <xarray.DataTree 'NEMO model'>
# Group: /
# │   Dimensions:               (time_counter: 594, axis_nbounds: 2)
# │   Coordinates:
# │     * time_counter          (time_counter) datetime64[ns] 5kB 1976-01-16T12:00:...
# │       time_centered         (time_counter) datetime64[ns] 5kB dask.array<chunksize=(1,), meta=np.ndarray>
# │   Dimensions without coordinates: axis_nbounds
# │   Data variables:
# │       time_centered_bounds  (time_counter, axis_nbounds) datetime64[ns] 10kB dask.array<chunksize=(1, 2), meta=np.ndarray>
# │       time_counter_bounds   (time_counter, axis_nbounds) datetime64[ns] 10kB dask.array<chunksize=(1, 2), meta=np.ndarray>
# │   Attributes:
# │       nftype:   T
# │       iperio:   True
# ├── Group: /gridT
# │       Dimensions:       (j: 3605, i: 4320, k: 75)
# │       Coordinates:
# │         * j             (j) int64 29kB 1 2 3 4 5 6 7 ... 3600 3601 3602 3603 3604 3605
# │         * i             (i) int64 35kB 1 2 3 4 5 6 7 ... 4315 4316 4317 4318 4319 4320
# ...

# %% [markdown]
# #### **1.2 Accessing pre-calculated AMOC diagnostics using OceanDataCatalog**
# ---
#
# * In addition to NPD ocean model variables, we can also access a range of pre-calculated diagnostics, such as the meridional overturning, heat and freshwater transports across the following trans-basin sections:
#
#     * Overturning in the Subpolar North Atlantic Program (**OSNAP**) array
#     * Rapid Climate Change-Meridional Overturning Circulation and Heatflux Array (**RAPID-MOCHA**) at 26.5°N
#     * Meridional Overturning Variability Experiment (**MOVE**) array at 16°N
#     * South Atlantic Meridional overturning circulation Basin-wide Array (**SAMBA**) array at 34.5°S
#
# * The latter three diagnostic datasets are calculated using the Meridional ovErTurning ciRculation diagnostIC ([**METRIC**](https://github.com/AMOCcommunity/metric)) package.
#
# * We can access these diagnostics by searching the **OceanDataCatalog** for any *Items* with identifiers containing the key word `"tn"`, which corresponds to transects which are defined on the native NEMO model grid:

# %%
catalog.search(collection='noc-npd-era5', item_name='tn')
# Out:
#             * Item ID: noc-npd-era5/npd-eorca1-era5v1/r1i1c1f1/tn/M1m/MOVE_16N
#               Title: M1m/MOVE_16N Icechunk repository
#               Description: **Monthly mean ocean physics transect outputs defined at MOVE_16N.**
#
# **OceanDataCatalog Access:**
# `catalog.open_dataset(id='noc-npd-era5/npd-eorca1-era5v1/r1i1c1f1/tn/M1m/MOVE_16N')`
#               Platform: tn
#               Start Date: 1976-01-01T00:00:00Z
#               End Date: 2025-07-31T00:00:00Z
#
#
#             * Item ID: noc-npd-era5/npd-eorca1-era5v1/r1i1c1f1/tn/M1m/SAMBA_34_5S
#               Title: M1m/SAMBA_34_5S Icechunk repository
#               Description: **Monthly mean global ocean scalar outputs.**
#
# **OceanDataCatalog Access:**
# `catalog.open_dataset(id='noc-npd-era5/npd-eorca1-era5v1/r1i1c1f1/tn/M1m/SAMBA_34_5S')`
#               Platform: tn
#               Start Date: 1976-01-01T00:00:00Z
#               End Date: 2025-07-31T00:00:00Z
#
#
# ...

# %%
# Opening eORCA1 ERA5 v1 RAPID 26N dataset:
ds_eorca1_rapid = catalog.open_dataset(id="noc-npd-era5/npd-eorca1-era5v1/r1i1c1f1/tn/M1m/RAPID_26N")

ds_eorca1_rapid
# Out:
# <xarray.Dataset> Size: 158MB
# Dimensions:        (time: 595, z: 75, xbounds: 72, x: 71)
# Coordinates:
#   * time           (time) datetime64[ns] 5kB 1976-01-16T12:00:00 ... 2025-07-...
#   * z              (z) float64 600B 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * xbounds        (xbounds) float64 576B -81.0 -80.0 -79.0 ... -11.0 -9.998
#   * x              (x) float64 568B -80.5 -79.5 -78.5 ... -12.5 -11.5 -10.5
# Data variables: (12/62)
#     dh             (time, z, xbounds) float64 26MB dask.array<chunksize=(1, 75, 72), meta=np.ndarray>
#     dx             (x) float64 568B dask.array<chunksize=(71,), meta=np.ndarray>
#     ekman          (time) float64 5kB dask.array<chunksize=(298,), meta=np.ndarray>
#     dz             (z) float64 600B dask.array<chunksize=(75,), meta=np.ndarray>
#     fw_geoint      (time) float64 5kB dask.array<chunksize=(298,), meta=np.ndarray>
#     fw_gyre_rapid  (time) float64 5kB dask.array<chunksize=(298,), meta=np.ndarray>
# ...

# %%
# Opening eORCA025 ERA5 v1 RAPID 26N dataset:
ds_eorca025_rapid = catalog.open_dataset(id="noc-npd-era5/npd-eorca025-era5v1/r1i1c1f1/tn/M1m/RAPID_26N")

ds_eorca025_rapid
# Out:
# <xarray.Dataset> Size: 612MB
# Dimensions:        (time: 595, z: 75, xbounds: 284, x: 283)
# Coordinates:
#   * time           (time) datetime64[ns] 5kB 1976-01-16T12:00:00 ... 2025-07-...
#   * z              (z) float64 600B 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * xbounds        (xbounds) float64 2kB -80.88 -80.63 -80.38 ... -10.37 -10.12
#   * x              (x) float64 2kB -80.75 -80.5 -80.25 ... -10.75 -10.5 -10.25
# Data variables: (12/62)
#     dh             (time, z, xbounds) float64 101MB dask.array<chunksize=(1, 75, 284), meta=np.ndarray>
#     ekman          (time) float64 5kB dask.array<chunksize=(298,), meta=np.ndarray>
#     fc             (time) float64 5kB dask.array<chunksize=(298,), meta=np.ndarray>
#     fw_fc          (time) float64 5kB dask.array<chunksize=(298,), meta=np.ndarray>
#     dz             (z) float64 600B dask.array<chunksize=(75,), meta=np.ndarray>
#     fw_gyre_model  (time) float64 5kB dask.array<chunksize=(298,), meta=np.ndarray>
# ...

# %%
# Opening eORCA12 ERA5 v1 RAPID 26N dataset:
ds_eorca12_rapid = catalog.open_dataset(id="noc-npd-era5/npd-eorca12-era5v1/r1i1c1f1/tn/M1m/RAPID_26N")

ds_eorca12_rapid
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:        (time: 588, z: 75, xbounds: 852, x: 851)
# Coordinates:
#   * time           (time) datetime64[ns] 5kB 1976-01-16T12:00:00 ... 2024-12-...
#   * z              (z) float64 600B 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * xbounds        (xbounds) float64 7kB -80.96 -80.88 -80.79 ... -10.12 -10.04
#   * x              (x) float64 7kB -80.92 -80.83 -80.75 ... -10.25 -10.17 -10.08
# Data variables: (12/62)
#     fw_geoint      (time) float64 5kB dask.array<chunksize=(12,), meta=np.ndarray>
#     ekman          (time) float64 5kB dask.array<chunksize=(12,), meta=np.ndarray>
#     dh             (time, z, xbounds) float64 301MB dask.array<chunksize=(1, 75, 852), meta=np.ndarray>
#     fc             (time) float64 5kB dask.array<chunksize=(12,), meta=np.ndarray>
#     fw_ek          (time) float64 5kB dask.array<chunksize=(12,), meta=np.ndarray>
#     fw_fc          (time) float64 5kB dask.array<chunksize=(12,), meta=np.ndarray>
# ...

# %% [markdown]
# #### **1.3 Accessing AMOC Observations**
# ---
#
# * We can access [**RAPID 26.5N**](https://rapid.ac.uk/data) AMOC observations stored in the JASMIN object store using `xarray.open_zarr()`:

# %%
# Define URL to RAPID Zarr dataset:
url = "https://noc-msm-o.s3-ext.jc.rl.ac.uk/ocean-obs/RAPID/moc_transports_v2024.1/"

# Open RAPID dataset:
ds_rapid = xr.open_zarr(url, zarr_format=3)

ds_rapid
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:       (time: 14599)
# Coordinates:
#   * time          (time) datetime64[ns] 117kB 2004-04-02 ... 2024-03-27
# Data variables:
#     t_gs10        (time) float64 117kB dask.array<chunksize=(14599,), meta=np.ndarray>
#     t_therm10     (time) float64 117kB dask.array<chunksize=(14599,), meta=np.ndarray>
#     t_umo10       (time) float64 117kB dask.array<chunksize=(14599,), meta=np.ndarray>
#     t_ek10        (time) float64 117kB dask.array<chunksize=(14599,), meta=np.ndarray>
#     t_ud10        (time) float64 117kB dask.array<chunksize=(14599,), meta=np.ndarray>
#     moc_mar_hc10  (time) float64 117kB dask.array<chunksize=(14599,), meta=np.ndarray>
#     t_aiw10       (time) float64 117kB dask.array<chunksize=(14599,), meta=np.ndarray>
#     t_ld10        (time) float64 117kB dask.array<chunksize=(14599,), meta=np.ndarray>
#     t_bw10        (time) float64 117kB dask.array<chunksize=(14599,), meta=np.ndarray>
# Attributes:
# ...

# %% [markdown]
# * We can access [**Overturning in the Subpolar North Atlantic (OSNAP)**](https://www.o-snap.org/data-access/) AMOC observations stored in the JASMIN object store using `xarray.open_zarr()`:

# %%
# Define URL to OSNAP Zarr dataset:
url = "https://noc-msm-o.s3-ext.jc.rl.ac.uk/ocean-obs/OSNAP/OSNAP_MOC_MHT_MFT_TimeSeries_201408_202207_2025/"

# Open OSNAP dataset:
ds_osnap = xr.open_zarr(url, zarr_format=3)

ds_osnap
# Out:
# <xarray.Dataset> Size: 15kB
# Dimensions:       (TIME: 96)
# Coordinates:
#   * TIME          (TIME) datetime64[ns] 768B 2014-08-01T12:00:00 ... 2022-07-...
# Data variables: (12/18)
#     MFT_ALL       (TIME) float64 768B dask.array<chunksize=(96,), meta=np.ndarray>
#     MFT_ALL_ERR   (TIME) float64 768B dask.array<chunksize=(96,), meta=np.ndarray>
#     MFT_EAST      (TIME) float64 768B dask.array<chunksize=(96,), meta=np.ndarray>
#     MFT_EAST_ERR  (TIME) float64 768B dask.array<chunksize=(96,), meta=np.ndarray>
#     MFT_WEST      (TIME) float64 768B dask.array<chunksize=(96,), meta=np.ndarray>
#     MFT_WEST_ERR  (TIME) float64 768B dask.array<chunksize=(96,), meta=np.ndarray>
#     ...            ...
#     MOC_ALL       (TIME) float64 768B dask.array<chunksize=(96,), meta=np.ndarray>
#     MOC_ALL_ERR   (TIME) float64 768B dask.array<chunksize=(96,), meta=np.ndarray>
#     MOC_EAST      (TIME) float64 768B dask.array<chunksize=(96,), meta=np.ndarray>
# ...
